# %% [markdown]
# <a href="https://colab.research.google.com/github/drmuruga/Tardigrade-CAHS-d-simulation/blob/main/Tardigrade_CAHS_d_simulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Create the directory structure
# !mkdir -p src data/raw data/processed

# Install dependencies safely
# !pip install openmm py3Dmol
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.4/14.4 MB 73.0 MB/s eta 0:00:00
# ...
